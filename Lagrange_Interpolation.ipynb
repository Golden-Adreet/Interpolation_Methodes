# %% [markdown]
# <a href="https://colab.research.google.com/github/Golden-Adreet/Interpolation_Methodes/blob/main/Lagrange_Interpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt;import numpy as np

# %%
def leq(x,n,val):
  a = 1
  for i in x:
    if n!=i:
      a*= float((val-i)/(n-i) )
  return a
def lagrange_interpolation(x:list,y:list,val:float):
  sum = 0
  for i in range(len(x)):
    sum+=y[i]*leq(x,x[i],val)
  return sum

# %%
x=[5,10,12,20,25,30]
y=[45,105,174,259,364,496]
#interpolation using scipy
y2=interp1d(x,y)
#default is linear
y3=interp1d(x,y,kind='cubic')
print (y2)
plt.subplot(1,2,1)
plt.title('Plot using Scipy')
plt.plot(x,y,'o',x,y2(x),x,y3(x),'-')
plt.subplot(1,2,2)
plt.title('Plot using Lagrange interpolation')
val = float(input('Enter a digit to interpolate:'))
print(f'the interpolated value for {val} is:{lagrange_interpolation(x,y,val)}')
a = np.linspace(5,30,1000)
b = np.array([lagrange_interpolation(x,y,i) for i in a])
plt.plot(x,y,'o',a,b)
plt.show()
# Out:
# ...
# Enter a digit to interpolate:25
# the interpolated value for 25.0 is:364.0

# %%
import numpy as np
